# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import math
# from mpl_toolkits.axes_grid1.inset_locator import (inset_axes, InsetPosition,
#                                                   mark_inset)

# %% [markdown]
# ## Defintions

# %%
#See this website for a,b, and c values http://lampx.tugraz.at/~hadley/ss1/crystaldiffraction/atomicformfactors/formfactors.php

def ff(Q, a, b, c):
    Q = np.array(Q)
    Q = Q / (4 * np.pi)
    fofQ = a[0] * np.exp(-b[0] * (Q/4*np.pi)**2) + \
           a[1] * np.exp(-b[1] * (Q/4*np.pi)**2) + \
           a[2] * np.exp(-b[2] * (Q/4*np.pi)**2) + \
           a[3] * np.exp(-b[3] * (Q/4*np.pi)**2) + c
    return fofQ

# %% [markdown]
# ## Calculation of Q from Lattice Parameters (For Beamtime purposes)

# %%
#10 rod
a = 2.708 #Equivalent to b for Hexagonal System
c = 4.268
h = 1
k = 1
l = np.linspace(0,6,600)

Q = 2*np.pi*(np.sqrt((4/3*(h**2+h*k+k**2)/a)+(l**2/c**2)))

plt.plot(l,Q)
plt.xlabel('l')
plt.ylabel('Q [1/$\AA$]')
# Out:
# Text(0, 0.5, 'Q [1/$\\AA$]')

# %%
import numpy as np

# Define lattice parameters and indices
a_crys = 2.708
c_crys = 4.268
h = 1
k = 1

# Define Q values as a numpy array
Q = np.linspace(2.5, 10, 600)

# Initialize an empty list for l values
l = []

# Loop through Q values and calculate l
for i in Q:
    # Calculate the term inside the square root
    term = (i / (2 * np.pi))**2 - (4 / 3) * ((h**2 + h * k + k**2) / a_crys**2)
    
    # Check if the term is non-negative to avoid complex numbers
    if term >= 0:
        l.append(c_crys * np.sqrt(term))
    else:
        l.append(np.nan)  # Handle negative values with NaN

# Convert l to a numpy array for easier processing if needed
l = np.array(l)

# %%
# Loading the data
P_25_L_1 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\100-103\8.28.24_25C_Pristine_0.1_0.9_L")
P_25_SFnorm_1 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\100-103\8.28.24_25C_Pristine_0.1_0.9_SFnorm")

P_25_L_2 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\100-103\8.28.24_25C_Pristine_1.1_1.9_L")
P_25_SFnorm_2 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\100-103\8.28.24_25C_Pristine_1.1_1.9_SFnorm")

P_25_L_3 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\100-103\8.28.24_25C_Pristine_2.1_2.9_L")
P_25_SFnorm_3 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\100-103\8.28.24_25C_Pristine_2.1_2.9_SFnorm")

P_25_L_4 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\103-105\9.12.24_25C_Ru1_Pristine_3.1_3.9_L")
P_25_SFnorm_4 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\103-105\9.12.24_25C_Ru1_Pristine_3.1_3.9_SFnorm")

P_25_L_5 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\103-105\9.12.24_25C_Ru1_Pristine_4.1_4.9_L")
P_25_SFnorm_5 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\103-105\9.12.24_25C_Ru1_Pristine_4.1_4.9_SFnorm")

P_25_L_6 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\105-107\9.4.24_25C_Pristine_5.1_5.9_L")
P_25_SFnorm_6 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\105-107\9.4.24_25C_Pristine_5.1_5.9_SFnorm")

# Loading the data
P_25_SF_1 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\100-103\8.28.24_25C_Pristine_0.1_0.9_SF")

P_25_SF_2 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\100-103\8.28.24_25C_Pristine_1.1_1.9_SF")

P_25_SF_3 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\100-103\8.28.24_25C_Pristine_2.1_2.9_SF")

P_25_SF_4 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\103-105\9.12.24_25C_Ru1_Pristine_3.1_3.9_SF")

P_25_SF_5 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\103-105\9.12.24_25C_Ru1_Pristine_4.1_4.9_SF")

P_25_SF_6 = np.loadtxt(r"D:\CTR_MyDrive\Extracted_2D\Ru1_Pristine\105-107\9.4.24_25C_Pristine_5.1_5.9_SF")

P_25_SF_final_1= P_25_SFnorm_1*P_25_SF_1[0]
P_25_SF_final_2 = P_25_SFnorm_1*P_25_SF_1[0]
P_25_SF_final_3 = P_25_SFnorm_1*P_25_SF_1[0]
P_25_SF_final_4 = P_25_SFnorm_1*P_25_SF_1[0]
P_25_SF_final_5 = P_25_SFnorm_1*P_25_SF_1[0]
P_25_SF_final_6 = P_25_SFnorm_1*P_25_SF_1[0]

# %%
#0-1 L, delete [0] and greater then 0.8
P_25_L_1_crop = []
P_25_SFnorm_1_crop = []
for index, (x, y) in enumerate(zip(P_25_L_1, P_25_SFnorm_1)):
    if index >= 1:
        if x <= 0.8:
            P_25_L_1_crop.append(x)
            P_25_SFnorm_1_crop.append(y)

#1-2 Nothing
P_25_L_2_crop = P_25_L_2
P_25_SFnorm_2_crop = P_25_SFnorm_2

#2-3 cut {5:]
P_25_L_3_crop = []
P_25_SFnorm_3_crop = []
for index, (x, y) in enumerate(zip(P_25_L_3, P_25_SFnorm_3)):
    if index <= 5 or 2.8 <= x:
        continue
    else:
        P_25_L_3_crop.append(x)
        P_25_SFnorm_3_crop.append(y)

#3-4 cut [0] and detector gap index [9-19]
P_25_L_4_crop = []
P_25_SFnorm_4_crop = []
for index, (x, y) in enumerate(zip(P_25_L_4, P_25_SFnorm_4)):
    if index == 0 or 9 <= index <= 19 or 3.8 <= x:
        continue
    else:
        P_25_L_4_crop.append(x)
        P_25_SFnorm_4_crop.append(y)

#4-5 delete [5:] and det gap 26-35 skipped 26
P_25_L_5_crop = []
P_25_SFnorm_5_crop = []
for index, (x, y) in enumerate(zip(P_25_L_5, P_25_SFnorm_5)):
    if index <= 5 or 26 <= index <= 35 or x >= 4.85:
        continue
    else:
        P_25_L_5_crop.append(x)
        P_25_SFnorm_5_crop.append(y)

#5-6 delete [3] and gap 38-50 and skipped index as 77
P_25_L_6_crop = []
P_25_SFnorm_6_crop = []
for index, (x, y) in enumerate(zip(P_25_L_6, P_25_SFnorm_6)):
    if index <= 3 or 38 <= index <= 50 or index == 77 or 5.8 <= x:
        continue
    else:
        P_25_L_6_crop.append(x)
        P_25_SFnorm_6_crop.append(y)

# %%
# Concatenating SF data
P_25_SF_full = np.concatenate([P_25_SFnorm_1_crop, P_25_SFnorm_2_crop, P_25_SFnorm_3_crop, P_25_SFnorm_4_crop, P_25_SFnorm_5_crop, P_25_SFnorm_6_crop], axis=0)

# Concatenating L data (fixing the typo)
P_25_l_full = np.concatenate([P_25_L_1_crop, P_25_L_2_crop, P_25_L_3_crop, P_25_L_4_crop, P_25_L_5_crop, P_25_L_6_crop], axis=0)

P_25_l_full = np.nan_to_num(P_25_l_full, 0.0)
P_25_SF_full = np.nan_to_num(P_25_SF_full, 0.0)

P_25_SF_norm = P_25_SF_full/P_25_SF_full[0]

P_25_SF_LF = []
for (i, j) in zip(P_25_l_full, P_25_SF_full):
    P_25_SF_LF.append(j * np.sqrt(2**2 + (2*np.pi*i/4.27)**2))

# %% [markdown]
# ## Form Factor Calculation

# %%
#Redefining formfactor to be a function of Q
a = [19.2674, 12.9182, 4.86337, 1.56756]
b = [0.80852, 8.43467, 24.7997, 94.2928]
c = [5.37874]

l = np.array(P_25_l_full)
# l = np.linspace(0,6,600)
Q = 2*np.pi * (np.sqrt( (4/3) * ( (h**2 + h*k + k**2)/a_crys**2 ) + (l**2/c_crys**2) ) )


# a = [18.5003, 13.1787, 4.71304, 2.18535]
# b = [0.844582, 8.12534, 0.36495, 20.8504]
# c = [1.42357]

ff_Ru_B = ff(Q,a,b,c)

plt.plot(l, ff_Ru_B)
plt.xlabel('l')
plt.ylabel('form factor')
# Out:
# Text(0, 0.5, 'form factor')

# %%
len(Q)
# Out:
# 347

# %% [markdown]
# ## Calculation of CTR

# %%
h = 1
k = 0
h_inv = -h
k_inv = -k
c = 4.268
Q = np.array(Q)
#DBW Calculation
u_bulk = 0.00
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

u_surfa = 0.00
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

sig = 0.5
# A = 0.5
# rho = A*np.exp(-Q*sig**2)

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2
# F_CTR = (ff_Ru_B * DBW_Ru_bulk) * F_bulk_inv
# F_CTR = (ff_Ru_B * rho) * (F_bulk + F_bulk_inv) / 2 

# # #Surface Scattering - 1st Layer
# outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
# outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
# outer_term_full = (outer_term + outer_term_inv) / 2

# z0a = 0.0
# layer1_PF = np.exp((-1j * 2 * np.pi *l/c * (c+z0a)/2)) #Phase Factor for "single" scattering events occuring at the crystal surfae in the normal direction

# #Surface Scattering - 1st Layer
outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)
# F_Surf = (F_Sb)

F_Total = F_CTR + F_Surf

plt.close('all')
# plt.plot(l,den)
plt.yscale('log')
plt.scatter(l,np.abs(F_CTR)**2, label = 'Bulk')
# plt.scatter(l,np.abs(F_Total)**2, label = 'Total')
# plt.scatter(l,np.abs(F_Surf)**2, label = 'Surface')
plt.legend()
plt.yscale('log')
# plt.ylim(top = 10**4)
plt.show()

# %% [markdown]
# ## Changing the DBW of just bulk

# %%
h = 1
k = 0
h_inv = -h
k_inv = -k
c = 4.268

#DBW Calculation
u_bulk = 0.0018
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

F_Total = F_CTR

#DBW Calculation
u_bulk = 0.0021
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

F_001 = F_CTR

#DBW Calculation
u_bulk = 0.0023
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

F_002 = F_CTR

#DBW Calculation
u_bulk = 0.0025
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

F_003 = F_CTR

#DBW Calculation
u_bulk = 0.0028
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

F_004 = F_CTR

# %matplotlib widget
plt.close('all')
# plt.plot(l,den)
plt.yscale('log')
plt.scatter(l,np.abs(F_Total)**2, label = '<u>$^2$ = 0.0018', color = '#824C71', s = 15)
# plt.scatter(l,np.abs(F_001)**2, label = '50')
plt.scatter(l,np.abs(F_002)**2, label = '<u>$^2$ = 0.0023', color = '#DC965A', s = 15)
# plt.scatter(l,np.abs(F_003)**2, label = '150')
plt.scatter(l,np.abs(F_004)**2, label = '<u>$^2$ = 0.0028', color = '#8DA9C4', s = 15)
# plt.title('No Surface Layer')
# plt.ylim(top = 10**8, bottom = 10**6)
plt.legend(frameon = False, fontsize = 14)
plt.xlabel('L (r.l.u)', fontsize = 14)
plt.ylabel('|SF|$^2$', fontsize = 14)
plt.yscale('log')
plt.xlim(right = 5, left = 0)
# plt.ylim(top = 10**4)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
h = 1
k = 0
h_inv = -h
k_inv = -k
c = 4.268

# l = np.linsapce(0,6,600)

#DBW Calculation
u_bulk = 0.000
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.00
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.1
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_Total = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.001
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.0015
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_001 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.005
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.0075
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_002 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.01
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.015
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_003 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.05
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.075
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_004 = F_CTR + F_Surf

# %matplotlib widget
plt.close('all')
# plt.plot(l,den)
plt.yscale('log')
# plt.scatter(l,np.abs(F_Total)**2, label = 'MSD bulk = 0')
# plt.scatter(l,np.abs(F_001)**2, label = 'MSD bulk = 0.001')
# plt.scatter(l,np.abs(F_002)**2, label = 'MSD bulk = 0.002')
# plt.scatter(l,np.abs(F_003)**2, label = 'MSD bulk = 0.003')
# plt.scatter(l,np.abs(F_004)**2, label = 'MSD bulk = 0.004')

plt.scatter(l,np.abs(F_Total)**2, label = 'MSD bulk = 0')
plt.scatter(l,np.abs(F_001)**2, label = 'MSD bulk = 0.001')
# plt.scatter(l,np.abs(F_002)**2, label = 'MSD bulk = 0.005')
# plt.scatter(l,np.abs(F_003)**2, label = 'MSD bulk = 0.01')
# plt.scatter(l,np.abs(F_004)**2, label = 'MSD bulk = 0.05')
plt.title('Surface Layer with MSD 2x bulk no surface expansion/contraction')

# plt.xlim(right = 5)
# plt.ylim(top = 10**8, bottom = 10**6)
plt.legend()
plt.yscale('log')
# plt.ylim(top = 10**4)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
h = 1
k = 0
h_inv = -h
k_inv = -k
c = 4.268

#DBW Calculation
u_bulk = 0.000
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.00
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_Total = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.003
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.003
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_001 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.003
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.003
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.05
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_002 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.003
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.003
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = -0.05
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_003 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.1
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.075
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_004 = F_CTR + F_Surf

# %matplotlib widget
plt.close('all')
# plt.plot(l,den)
plt.yscale('log')
# plt.scatter(l,np.abs(F_Total)**2, label = 'MSD bulk = 0')
# plt.scatter(l,np.abs(F_001)**2, label = 'MSD bulk = 0.001')
# plt.scatter(l,np.abs(F_002)**2, label = 'MSD bulk = 0.002')
# plt.scatter(l,np.abs(F_003)**2, label = 'MSD bulk = 0.003')
# plt.scatter(l,np.abs(F_004)**2, label = 'MSD bulk = 0.004')

# plt.scatter(l,np.abs(F_Total)**2, label = 'Bulk Crystal: <u$^2$> = 0.003', color = 'k', s = 10)
# plt.scatter(l,np.abs(F_001)**2, label = 'Offset Z = 0', color = '#824C71', s = 15)
plt.scatter(l,np.abs(F_002)**2, label = 'Offset Z = 0.05', color = '#DC965A', s = 15)
# plt.scatter(l,np.abs(F_003)**2, label = 'Offset Z = -0.05', color = '#8DA9C4', s = 15)
# plt.scatter(l,np.abs(F_004)**2, label = 'MSD bulk = 0.05')
# plt.title('Various CTR Models for Ru 10L at 200 $\degree$C')

plt.xlim(right = 5)
# plt.ylim(top = 10**8, bottom = 10**6)
plt.xlabel('L (r.l.u)', fontsize = 14)
plt.ylabel('|SF|$^2$', fontsize = 14)
plt.legend(frameon = False, fontsize = 14)
plt.yscale('log')
# plt.ylim(top = 10**4)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
h = 1
k = 0
h_inv = -h
k_inv = -k
c = 4.268

#DBW Calculation
u_bulk = 0.000
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.00
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_Total = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.003
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.004
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_001 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.003
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.004
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.05
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_002 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.003
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.004
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = -0.05
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_003 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.1
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.075
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_004 = F_CTR + F_Surf

# %matplotlib widget
plt.close('all')
# plt.plot(l,den)
plt.yscale('log')
# plt.scatter(l,np.abs(F_Total)**2, label = 'MSD bulk = 0')
# plt.scatter(l,np.abs(F_001)**2, label = 'MSD bulk = 0.001')
# plt.scatter(l,np.abs(F_002)**2, label = 'MSD bulk = 0.002')
# plt.scatter(l,np.abs(F_003)**2, label = 'MSD bulk = 0.003')
# plt.scatter(l,np.abs(F_004)**2, label = 'MSD bulk = 0.004')

plt.scatter(l,np.abs(F_Total)**2, label = 'Bulk Crystal: <u$^2$> = 0.003', color = 'k', s = 10)
plt.scatter(l,np.abs(F_001)**2, label = 'Surface Layer: <u$^2$> = 0.004, Offset Z = 0', color = '#521945', s = 10)
plt.scatter(l,np.abs(F_002)**2, label = 'Surface Layer: <u$^2$> = 0.004, Offset Z = 0.05', color = '#D98324', s = 10)
plt.scatter(l,np.abs(F_003)**2, label = 'Surface Layer: <u$^2$> = 0.004, Offset Z = -0.05', color = '#4BC6B9', s = 10)
# plt.scatter(l,np.abs(F_004)**2, label = 'MSD bulk = 0.05')
plt.title('Various CTR Models for Ru 10L at 200 $\degree$C')

plt.xlim(right = 5)
# plt.ylim(top = 10**8, bottom = 10**6)
plt.xlabel('L (r.l.u)', fontsize = 14)
plt.ylabel('|SF|$^2$', fontsize = 14)
plt.legend(frameon = False)
plt.yscale('log')
# plt.ylim(top = 10**4)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
h = 1
k = 0
h_inv = -h
k_inv = -k
c = 4.268

#DBW Calculation
u_bulk = 0.002
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.00
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_Total = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.002
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.003
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_001 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.002
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.004
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.0
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_002 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.002
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.005
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_003 = F_CTR + F_Surf

#DBW Calculation
u_bulk = 0.1
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.075
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_004 = F_CTR + F_Surf

# %matplotlib widget
plt.close('all')
# plt.plot(l,den)
plt.yscale('log')
# plt.scatter(l,np.abs(F_Total)**2, label = 'MSD bulk = 0')
# plt.scatter(l,np.abs(F_001)**2, label = 'MSD bulk = 0.001')
# plt.scatter(l,np.abs(F_002)**2, label = 'MSD bulk = 0.002')
# plt.scatter(l,np.abs(F_003)**2, label = 'MSD bulk = 0.003')
# plt.scatter(l,np.abs(F_004)**2, label = 'MSD bulk = 0.004')

plt.scatter(l,np.abs(F_Total)**2, label = 'Bulk Crystal: <u$^2$> = 0.003', color = 'k', s = 10)
plt.scatter(l,np.abs(F_001)**2, label = 'Surface Layer: <u$^2$> = 0.003, Offset Z = 0', color = '#521945', s = 10)
plt.scatter(l,np.abs(F_002)**2, label = 'Surface Layer: <u$^2$> = 0.004, Offset Z = 0', color = '#D98324', s = 10)
plt.scatter(l,np.abs(F_003)**2, label = 'Surface Layer: <u$^2$> = 0.005, Offset Z = 0', color = '#4BC6B9', s = 10)
# plt.scatter(l,np.abs(F_004)**2, label = 'MSD bulk = 0.05')
plt.title('Various CTR Models for Ru 10L at 75 $\degree$C')

plt.xlim(right = 5)
# plt.ylim(top = 10**8, bottom = 10**6)
plt.xlabel('L (r.l.u)', fontsize = 14)
plt.ylabel('|SF|$^2$', fontsize = 14)
plt.legend(frameon = False, loc = 'lower left')
plt.yscale('log')
# plt.ylim(top = 10**4)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
h = 1
k = 0
h_inv = -h
k_inv = -k
c = 4.268
Q = np.array(Q)
#DBW Calculation
u_bulk = 0.00
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

u_surfa = 0.00
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

sig = 0.5
# A = 0.5
# rho = A*np.exp(-Q*sig**2)

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2
F_CTR_inv = (ff_Ru_B * DBW_Ru_bulk) * F_bulk_inv
F_CTR_n = (ff_Ru_B * DBW_Ru_bulk) * F_bulk

F_N = F_CTR_n
F_I = F_CTR_inv
F_Bulk = F_CTR

plt.close('all')

# Create a figure and a 1x3 subplot
fig, axes = plt.subplots(1, 3, figsize=(10, 5), sharey=True)

# First subplot
axes[0].scatter(l, np.abs(F_CTR_n)**2, s = 25, color = 'k')
axes[0].set_title('F$_{CTR}$: $\Phi$$_n$', fontsize = 14)
axes[0].set_ylabel('|SF|$^2$', fontsize = 14)
axes[0].set_xlabel('L (r.l.u.)', fontsize = 14)

# Second subplot
axes[1].scatter(l, np.abs(F_CTR_inv)**2, s = 25, color = 'k')
axes[1].set_title('F$_{CTR}$: $\Phi$$_i$', fontsize = 14)
axes[1].set_xlabel('L (r.l.u.)', fontsize = 14)

# Third subplot
axes[2].scatter(l, np.abs(F_CTR)**2, s = 25, color = 'k')
axes[2].set_title('F$_{CTR}$', fontsize = 14)
axes[2].set_yscale('log')
axes[2].set_ylim(bottom = 10**1)
axes[2].set_xlabel('L (r.l.u.)', fontsize = 14)
axes[2].set_ylabel('|SF|$^2$', fontsize = 14)


# Overall layout adjustments
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
h = 1
k = 0
h_inv = -h
k_inv = -k
c = 4.28

################## BUlK RU AT 25 C SIM ###########
""" No difference in surface layer """

#DBW Calculation
u_bulk = 0.0027
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.0027
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.00
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_Total = F_CTR + F_Surf


###################### BULK RU at 25 C Sim using first two layers from Travis's data ##################

#DBW Calculation
u_bulk = 0.0027
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.0044
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.005 #Confirm this with Travis?
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_001 = F_CTR + F_Surf

###################### BULK RU at 200 C Sim using first two layers from Travis's data ##################

#DBW Calculation
u_bulk = 0.0035
DBW_Ru_bulk = np.exp(-(Q**2*u_bulk)*2) 

#Bulk CTR Scattering
F_bulk = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h/3 + (2*k/3) - l/2)))
F_bulk_inv = (1 / (2*1j)) * (np.exp(-1j * np.pi * l) / np.sin(np.pi * l)) * (1 + np.exp(2 * np.pi * 1j * (h_inv/3 + (2*k_inv/3) - l/2)))
F_CTR = (ff_Ru_B * DBW_Ru_bulk) * (F_bulk + F_bulk_inv) / 2 

u_surfa = 0.0056
DBW_Ru_surfa = np.exp(-(Q**2*u_surfa)*2)

outer_term = np.exp(1j * 2 * np.pi * (h/3+ (2*k/3)))  #Phase Factor for sum of "single" scattering events occuring at the crystal surfae in the in-plane direction)
outer_term_inv = np.exp(1j * 2 * np.pi * (h_inv/3+ (2*k_inv/3)))
outer_term_full = (outer_term + outer_term_inv) / 2

z0a = 0.005 #Confirm this with Travis?
layer1_PF = np.exp((-1j * (2 * np.pi) * l/c * (c+z0a)/2))

F_Sa = (ff_Ru_B * DBW_Ru_surfa * layer1_PF)

F_Surf = outer_term_full * (F_Sa)

F_002 = F_CTR + F_Surf

# %%
plt.close('all')
plt.yscale('log')

plt.scatter(l,np.abs(F_Total)**2, label = 'Bulk Crystal: <u$^2$> = 0.002', color = 'k', s = 10)
plt.scatter(l,np.abs(F_001)**2, label = 'Surface Layer: <u$^2$> = 0.003, Offset Z = 0.005', color = '#521945', s = 10)
plt.scatter(l,np.abs(F_002)**2, label = 'Surface Layer: <u$^2$> = 0.003, Offset Z = 0.005', color = '#521949', s = 10)


plt.title('Various CTR Models for Ru 10L at 75 $\degree$C')

plt.xlim(right = 5)
# plt.ylim(top = 10**8, bottom = 10**6)
plt.xlabel('L (r.l.u)', fontsize = 14)
plt.ylabel('|SF|$^2$', fontsize = 14)
plt.legend(frameon = False, loc = 'lower left')
plt.yscale('log')
# plt.ylim(top = 10**4)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
